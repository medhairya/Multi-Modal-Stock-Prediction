# %%
# !pip install -q datasets huggingface_hub pandas matplotlib
# Out:
#   WARNING: The script pygmentize.exe is installed in 'C:\Users\hp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\hp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\hp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts' which is not on PATH.
# ...

# %%
from huggingface_hub import login

login("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")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from huggingface_hub import login
#       3 login("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")
#
# ModuleNotFoundError: No module named 'huggingface_hub'

# %%
from datasets import load_dataset

ds = load_dataset("TheFinAI/CLEF_Task3_Trading")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Pick a split (usually 'train'); fall back to first available.
split_name = "train" if "train" in df else list(df.keys())[0]
ds = df[split_name]

prices = ds["prices"]

# Make the 'prices' column plottable for common shapes.
# - list/array of numbers -> plot directly
# - list of lists -> flatten
# - list of dicts -> try common keys (price/close/value)
if len(prices) == 0:
    raise ValueError("'prices' is empty")

first = prices[0]
if isinstance(first, dict):
    key = next((k for k in ["price", "close", "value"] if k in first), None)
    if key is None:
        raise ValueError(f"'prices' appears to be dicts with keys {list(first.keys())}, can't infer numeric key")
    y = pd.to_numeric([p.get(key) for p in prices], errors="coerce")
elif isinstance(first, (list, tuple)):
    y = pd.to_numeric(pd.Series(prices).explode(), errors="coerce")
else:
    y = pd.to_numeric(prices, errors="coerce")

y = y.dropna().reset_index(drop=True)

plt.figure(figsize=(10, 4))
plt.plot(y)
plt.title(f"Prices (split: {split_name})")
plt.xlabel("Index")
plt.ylabel("Price")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
